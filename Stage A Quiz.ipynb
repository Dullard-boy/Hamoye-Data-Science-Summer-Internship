# %%
import pandas as pd

# %%
data=pd.read_excel('C:/Users/good/Desktop/HDSC Internship/Introduction to Python/FoodBalanceSheets_E_Africa_NOFLAG.xlsx')

# %%
data.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
data.shape
# Out:
# (60943, 12)

# %%
data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
data.dtypes
# Out:
# Area Code         int64
# Area             object
# Item Code         int64
# Item             object
# Element Code      int64
# Element          object
# Unit             object
# Y2014           float64
# Y2015           float64
# Y2016           float64
# Y2017           float64
# Y2018           float64
# dtype: object

# %%
data['Area'].value_counts()
# Out:
# Kenya                          1560
# Egypt                          1488
# Nigeria                        1474
# Côte d'Ivoire                  1467
# Senegal                        1462
# Cameroon                       1460
# Uganda                         1458
# Zambia                         1451
# Malawi                         1447
# Ethiopia                       1447
# Madagascar                     1439
# Mozambique                     1427
# Rwanda                         1426
# Angola                         1424
# United Republic of Tanzania    1419
# Congo                          1413
# Guinea                         1410
# Burkina Faso                   1409
# Niger                          1403
# South Africa                   1399
# Zimbabwe                       1393
# Morocco                        1393
# Botswana                       1378
# Mauritius                      1378
# Ghana                          1354
# Central African Republic       1344
# ...

# %%
data['Item'].value_counts()
# Out:
# Milk - Excluding Butter     1262
# Eggs                        1142
# Miscellaneous                911
# Cereals - Excluding Beer     714
# Oilcrops                     706
#                             ...
# Grand Total                  135
# Animal Products              135
# Vegetal Products             135
# Sugar non-centrifugal        121
# Population                    90
# Name: Item, Length: 119, dtype: int64

# %%
grouped_data=data.groupby('Area')

# %%
grouped_data

# %%
for group in grouped_data:
    print(group)
# Out:
# ('Algeria',       Area Code     Area  Item Code           Item  Element Code  \
# 0             4  Algeria       2501     Population           511
# 1             4  Algeria       2501     Population          5301
# 2             4  Algeria       2901    Grand Total           664
# 3             4  Algeria       2901    Grand Total           674
# 4             4  Algeria       2901    Grand Total           684
# ...         ...      ...        ...            ...           ...
# 1308          4  Algeria       2899  Miscellaneous          5142
# 1309          4  Algeria       2899  Miscellaneous           645
# 1310          4  Algeria       2899  Miscellaneous           664
# 1311          4  Algeria       2899  Miscellaneous           674
# 1312          4  Algeria       2899  Miscellaneous           684
#
#                                      Element             Unit     Y2014  \
# 0              Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
data[[ 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']].describe()
# Out:
#                Y2014          Y2015          Y2016          Y2017  \
# count   59354.000000   59395.000000   59408.000000   59437.000000
# mean      134.196282     135.235966     136.555222     140.917765
# std      1567.663696    1603.403984    1640.007194    1671.862359
# min     -1796.000000   -3161.000000   -3225.000000   -1582.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.090000       0.080000       0.080000       0.100000
# 75%         8.340000       8.460000       8.430000       9.000000
# max    176405.000000  181137.000000  185960.000000  190873.000000
#
#                Y2018
# count   59507.000000
# mean      143.758381
# std      1710.782658
# min     -3396.000000
# 25%         0.000000
# 50%         0.070000
# 75%         9.000000
# max    195875.000000

# %%
data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
data[[ 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']].describe()
# Out:
#                Y2014          Y2015          Y2016          Y2017  \
# count   59354.000000   59395.000000   59408.000000   59437.000000
# mean      134.196282     135.235966     136.555222     140.917765
# std      1567.663696    1603.403984    1640.007194    1671.862359
# min     -1796.000000   -3161.000000   -3225.000000   -1582.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.090000       0.080000       0.080000       0.100000
# 75%         8.340000       8.460000       8.430000       9.000000
# max    176405.000000  181137.000000  185960.000000  190873.000000
#
#                Y2018
# count   59507.000000
# mean      143.758381
# std      1710.782658
# min     -3396.000000
# 25%         0.000000
# 50%         0.070000
# 75%         9.000000
# max    195875.000000

# %%
data.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
item_group = data.groupby('Item')
print(item_group)

# %%
animal =item_group.get_group('Animal Products')

# %%
animal[['Y2014','Y2017']].sum()
# Out:
# Y2014    11935.65
# Y2017    11547.65
# dtype: float64

# %%
ele_group = data.groupby('Element')
import_quantity=ele_group.get_group('Import Quantity')

# %%
import_quantity[[ 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']].sum()
# Out:
# Y2014    274144.48
# Y2015    267018.46
# Y2016    286582.78
# Y2017    294559.09
# Y2018    287997.09
# dtype: float64

# %%
prod=ele_group.get_group('Production')
prod['Y2014'].sum()
# Out:
# 1931287.75

# %%
ele_group['Y2018'].sum()
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
ar=import_quantity.groupby('Area')
alg=ar.get_group('Algeria')
alg['Y2018'].sum()
# Out:
# 36238.29

# %%
area=data['Area'].value_counts()
area.shape
# Out:
# (49,)

# %%
item_group = data.groupby('Item')
animal=item_group.get_group('Animal fats')
animal[['Y2014','Y2018']].sum()
# Out:
# Y2014    209460.54
# Y2018    269648.27
# dtype: float64

# %%
pd.set_option('display.max_rows', None)
data['Item'].value_counts()
# Out:
# Milk - Excluding Butter            1262
# Eggs                               1142
# Miscellaneous                       911
# Cereals - Excluding Beer            714
# Oilcrops                            706
# Maize and products                  687
# Starchy Roots                       674
# Rice and products                   670
# Wheat and products                  653
# Pulses                              649
# Potatoes and products               641
# Animal fats                         639
# Pulses, Other and products          626
# Groundnuts (Shelled Eq)             617
# Sugar & Sweeteners                  613
# Sorghum and products                606
# Fats, Animals, Raw                  598
# Fruits - Excluding Wine             591
# Cereals, Other                      591
# Vegetables                          587
# Oilcrops, Other                     586
# Vegetables, Other                   583
# Beans                               580
# ...
